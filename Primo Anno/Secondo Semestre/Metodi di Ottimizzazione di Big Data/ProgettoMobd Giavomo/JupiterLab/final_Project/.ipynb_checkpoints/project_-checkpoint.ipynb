# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import BaggingClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
import sklearn.model_selection as model_select
from sklearn import svm

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import sklearn.model_selection as model_select
import sklearn.metrics as metrics
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.svm import SVC
from sklearn.decomposition import PCA
import pickle

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %% [markdown]
# # Importo Dataset

# %%
#Importo dati
dataset = pd.read_csv('training_set.csv')
dataset
# Out:
#             F1        F2        F3        F4        F5        F6        F7  \
# 0    -0.555694 -0.848258  0.132180 -4.061760  1.661394  2.219988  0.360537
# 1     0.293193 -2.628978 -1.154407  0.538828 -0.169857  3.487574  0.443397
# 2    -2.078656 -0.834492  1.241461  1.010122 -1.638526  0.247378 -1.887390
# 3    -1.294256 -2.804065 -1.335397 -1.351379 -0.327137  1.199219  0.262458
# 4    -0.525611  0.024948  1.609361 -0.248425  1.533188  0.580862  0.049771
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  0.405098  0.592920  2.441859 -1.134919  2.248627  2.509097 -0.227617
# 7996 -0.404388  1.813804 -2.483380  2.093664  0.139423  2.617027  0.489677
# 7997  0.233546 -1.003142 -2.121826  1.581558  1.152723 -0.987152  0.337969
# 7998  1.120382  0.194409 -0.672968  0.005154  2.290353  4.112554  0.720367
# 7999  0.994641 -1.185386 -3.610239  0.185566 -1.534623  3.021333 -0.721372
#
#             F8        F9       F10  ...       F12       F13       F14  \
# 0     2.537116 -0.613588  2.078144  ... -2.492234  0.808907 -1.078887
# 1    -0.006410 -0.125778  1.223669  ... -1.723842  1.772836  0.467387
# 2    -1.331368 -2.159086  0.002788  ... -1.686278 -1.047410 -1.133299
# 3     0.825120 -0.638883  1.660732  ...  4.437570 -0.093413  2.637345
# 4    -0.430270 -0.714264 -0.186867  ...  0.404803 -0.733368  1.288384
# ...        ...       ...       ...  ...       ...       ...       ...
# 7995  0.275321 -0.274926 -0.595862  ... -0.169544 -0.255823  2.695956
# 7996  1.387914 -0.363073  0.030530  ...  0.124103  0.056482 -0.333988
# 7997 -4.654229 -0.417682 -1.260857  ...  2.469214  2.782867  0.888288
# 7998  0.563533 -1.009534 -1.551473  ...  0.607569  3.102179  4.237942
# 7999 -3.250708 -0.034000 -0.102102  ... -3.273256  3.908861  0.809098
#
#            F15       F16       F17       F18       F19       F20  CLASS
# 0     3.438161  2.372122  1.899934  2.372122  2.219416  0.132180      2
# 1    -1.501851 -3.599221 -0.968531 -3.599221  1.127776 -1.154407      0
# 2    -1.953928 -1.149684  1.111692 -1.149684  0.134184  1.241461      1
# 3    -2.415704 -4.679002  0.511314 -4.679002  0.805571 -1.335397      0
# 4    -1.646543 -1.020989  0.658584 -1.020989  1.412792  1.609361      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 7995 -2.220396 -2.432903 -0.131110 -2.432903 -0.479939  2.441859      1
# 7996 -1.204211 -0.224673  1.521622 -0.224673 -1.096852 -2.483380      2
# 7997  0.335607 -2.248307 -1.386542 -2.248307  0.934043 -2.121826      0
# 7998 -0.710731 -0.359420 -1.500903 -0.359420 -0.658633 -0.672968      1
# 7999  2.970013 -2.104526 -0.419366 -2.104526  1.655029 -3.610239      3
#
# [8000 rows x 21 columns]

# %%
# Separiamo le classi dalle features
target = 'CLASS'
x = dataset.drop(target, axis=1)
print('Variabili Indipendenti X:\n', x)
# Out:
# Variabili Indipendenti X:
#              F1        F2        F3        F4        F5        F6        F7  \
# 0    -0.555694 -0.848258  0.132180 -4.061760  1.661394  2.219988  0.360537
# 1     0.293193 -2.628978 -1.154407  0.538828 -0.169857  3.487574  0.443397
# 2    -2.078656 -0.834492  1.241461  1.010122 -1.638526  0.247378 -1.887390
# 3    -1.294256 -2.804065 -1.335397 -1.351379 -0.327137  1.199219  0.262458
# 4    -0.525611  0.024948  1.609361 -0.248425  1.533188  0.580862  0.049771
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  0.405098  0.592920  2.441859 -1.134919  2.248627  2.509097 -0.227617
# 7996 -0.404388  1.813804 -2.483380  2.093664  0.139423  2.617027  0.489677
# 7997  0.233546 -1.003142 -2.121826  1.581558  1.152723 -0.987152  0.337969
# 7998  1.120382  0.194409 -0.672968  0.005154  2.290353  4.112554  0.720367
# 7999  0.994641 -1.185386 -3.610239  0.185566 -1.534623  3.021333 -0.721372
#
#             F8        F9       F10       F11       F12       F13       F14  \
# 0     2.537116 -0.613588  2.078144  0.128270 -2.492234  0.808907 -1.078887
# 1    -0.006410 -0.125778  1.223669  0.239508 -1.723842  1.772836  0.467387
# 2    -1.331368 -2.159086  0.002788 -0.397360 -1.686278 -1.047410 -1.133299
# 3     0.825120 -0.638883  1.660732 -2.045188  4.437570 -0.093413  2.637345
# 4    -0.430270 -0.714264 -0.186867  0.572004  0.404803 -0.733368  1.288384
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  0.275321 -0.274926 -0.595862  1.379110 -0.169544 -0.255823  2.695956
# 7996  1.387914 -0.363073  0.030530  0.962490  0.124103  0.056482 -0.333988
# 7997 -4.654229 -0.417682 -1.260857  4.472366  2.469214  2.782867  0.888288
# 7998  0.563533 -1.009534 -1.551473 -0.697174  0.607569  3.102179  4.237942
# 7999 -3.250708 -0.034000 -0.102102  6.857379 -3.273256  3.908861  0.809098
#
#            F15       F16       F17       F18       F19       F20
# 0     3.438161  2.372122  1.899934  2.372122  2.219416  0.132180
# 1    -1.501851 -3.599221 -0.968531 -3.599221  1.127776 -1.154407
# 2    -1.953928 -1.149684  1.111692 -1.149684  0.134184  1.241461
# 3    -2.415704 -4.679002  0.511314 -4.679002  0.805571 -1.335397
# 4    -1.646543 -1.020989  0.658584 -1.020989  1.412792  1.609361
# ...        ...       ...       ...       ...       ...       ...
# 7995 -2.220396 -2.432903 -0.131110 -2.432903 -0.479939  2.441859
# 7996 -1.204211 -0.224673  1.521622 -0.224673 -1.096852 -2.483380
# 7997  0.335607 -2.248307 -1.386542 -2.248307  0.934043 -2.121826
# 7998 -0.710731 -0.359420 -1.500903 -0.359420 -0.658633 -0.672968
# 7999  2.970013 -2.104526 -0.419366 -2.104526  1.655029 -3.610239
#
# [8000 rows x 20 columns]

# %%
# Classi
y = dataset[[target]]
print('\nVariabili Dipendenti Y:\n', y)
# Out:
# Variabili Dipendenti Y:
#        CLASS
# 0         2
# 1         0
# 2         1
# 3         0
# 4         1
# ...     ...
# 7995      1
# 7996      2
# 7997      0
# 7998      1
# 7999      3
#
# [8000 rows x 1 columns]

# %%
# Lista delle features
features_list = x.columns.values.tolist()
print('Lista Features:\n', features_list)
# Out:
# Lista Features:
#  ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17', 'F18', 'F19', 'F20']

# %%
# Split in training-set e test-set.
train_x, test_x, train_y, test_y = \
        model_select.train_test_split(x, y,
                                      test_size=0.2,
                                      random_state=42,
                                      stratify=y)
print('\nTraining set shape:', train_x.shape, train_y.shape)
print('Test set shape:', test_x.shape, test_y.shape)
# Out:
# Training set shape: (6400, 20) (6400, 1)
# Test set shape: (1600, 20) (1600, 1)

# %% [markdown]
# # Classi

# %%
# Creiamo la classe che rimpiazza gli outliers che ci servira per pipeline e perchè KNN non rimpiazza direttamente gli outliers
# ma i nan quindi bisogna anche ricreare il metodo fit e il trasform

class KNNReplacerIQR(KNNImputer):
    """Pipeline-compliant KNNReplacer, based on IQR."""

    def __init__(self, n_neighbors=5):
        super().__init__(n_neighbors=n_neighbors)
        self.lower_bound = None
        self.upper_bound = None
        self.imputer = KNNImputer(n_neighbors=n_neighbors)

    def fit(self, x, y=None):
        """Computes IQR bound and fits the imputer on the data."""
        x = pd.DataFrame(x)
        q1 = x.quantile(0.25)
        q3 = x.quantile(0.75)
        iqr = q3 - q1
        self.lower_bound = q1 - (3* iqr)
        self.upper_bound = q3 + (3* iqr)
        self.imputer.fit(
            x.where(~((x < self.lower_bound) | (x > self.upper_bound)), np.nan)
        )
        return self

    def transform(self, x, y=None):
        """Detects outliers and replaces them with the imputer."""
        x = pd.DataFrame(x)
        x.where(~((x < self.lower_bound) | (x > self.upper_bound)),
                np.nan,
                inplace=True)
        return self.imputer.transform(x)

# %%
   class DBScanner(DBSCAN):
        outliers = []
        def __init__(self,eps=10,min_samples=100):
            super().__init__(eps=eps,min_samples=min_samples)
            #self.Scanner = DBSCAN(eps=eps,min_samples=min_samples)
            
        def fit(self,x,y=None):
            x = pd.DataFrame(x)
            model = super().fit(x)
            outliers = x[model.labels_==-1].index.values
        
        def transform(self, x, y=None):
            x = pd.DataFrame(x).drop(index = outliers)
            return self.x

# %% [markdown]
# # Mia PIPELINE

# %%
def get_my_pipeline():
    
    # Definisco la mia Pipeline e lista di azioni da eseguire
    Pipe_Knn_Dbscan_Knn_QDA = Pipeline([('imputer' , KNNImputer()),
                                        ('cluster' , DBScanner()),
                                        ('replacer' , KNNReplacerIQR()),
                                        ('scaler' , RobustScaler()),
                                        ('classifier' , QuadraticDiscriminantAnalysis())
                                        ])
    
    Pipe_Knn_QDA = Pipeline([('imputer' , KNNImputer()),
                            ('replacer' , KNNReplacerIQR()),
                            ('scaler' , RobustScaler()),
                            ('classifier' , QuadraticDiscriminantAnalysis())
                            ])
    
    Pipe_Knn_Dbscan_Knn_Bagging = Pipeline([('imputer' , KNNImputer()),
                                        ('cluster' , DBScanner()),
                                        ('replacer' , KNNReplacerIQR()),
                                        ('scaler' , RobustScaler()),
                                        ('classifier' , BaggingClassifier(
                                                        base_estimator=QuadraticDiscriminantAnalysis(),
                                                        random_state = 42))
                                        ])
    
    Pipe_Knn_Bagging = Pipeline([('imputer' , KNNImputer()),
                                ('replacer' , KNNReplacerIQR()),
                                ('scaler' , RobustScaler()),
                                ('classifier' ,  BaggingClassifier(
                                                 base_estimator=QuadraticDiscriminantAnalysis(),
                                                 random_state = 42))
                                ])
    
    #Setto i parametri che dovrà usare Pipeline ad ogni iterazione
    grid_Pipe_Knn_Dbscan_Knn_QDA = {'imputer__n_neighbors' : [2, 5, 10],
                                    'cluster__eps' : [10, 15,20], #[0.1 , 0.5 , 1],
                                    'cluster__min_samples' : [500, 1000, 1500], #[5, 10, [100, 200, 1000],
                                    'replacer__n_neighbors' : [2, 5, 10]
                                    }
    
    grid_Pipe_Knn_QDA = {'imputer__n_neighbors' : [2, 5, 10] ,
                         'replacer__n_neighbors' : [2, 5, 10]
                        }
    
    grid_Pipe_Knn_Dbscan_Knn_Bagging = {'imputer__n_neighbors' : [2, 5, 10],
                                         'cluster__eps' : [0.1 , 0.5 , 1],#,5, 10, 15],
                                         'cluster__min_samples' : [500, 1000, 1500],#[5, 10, 100]
                                         'replacer__n_neighbors' : [2, 5, 10]
                                        }
    grid_Pipe_Knn_Bagging = {'imputer__n_neighbors' : [2, 5, 10] ,
                             'replacer__n_neighbors' : [2, 5, 10]
                            }
    
    #Definisco le grid search per le pipeline
    gs_QDA_knn_Dbscan = model_select.GridSearchCV( Pipe_Knn_Dbscan_Knn_QDA,
                                               param_grid =  grid_Pipe_Knn_Dbscan_Knn_QDA,
                                               scoring='f1_macro',
                                               cv=5,
                                               refit=True,
                                               n_jobs=-1) 
    
    
    gs_QDA_knn= model_select.GridSearchCV( Pipe_Knn_QDA,
                                               param_grid = grid_Pipe_Knn_QDA ,
                                               scoring='f1_macro',
                                               cv=5,
                                               refit=True,
                                               n_jobs=-1) 
    
    gs_Bagging_knn_Dbscan = model_select.GridSearchCV( Pipe_Knn_Dbscan_Knn_Bagging,
                                               param_grid =  grid_Pipe_Knn_Dbscan_Knn_Bagging,
                                               scoring='f1_macro',
                                               cv=5,
                                               refit=True,
                                               n_jobs=-1) 
    
    gs_Bagging_knn = model_select.GridSearchCV( Pipe_Knn_Bagging ,
                                               param_grid =  grid_Pipe_Knn_Bagging,
                                               scoring='f1_macro',
                                               cv=5,
                                               refit=True,
                                               n_jobs=-1) 
    
    # Lista pipeline
    grids = [gs_QDA_knn_Dbscan,
             gs_QDA_knn,
             gs_Bagging_knn_Dbscan,
             gs_Bagging_knn]
    
    #Dizionario delle pipeline
    grid_dict_pipe = {0: 'QDA-KNN-DBSCAN',
                  1: 'QDA-KNN',
                  2: 'BAGGING-KNN-DBSCAN',
                  3: 'BAGGING-KNN'}
    
    return grids, grid_dict_pipe

# %%
 # Definisco la mia Pipeline e lista di azioni da eseguire
Pipe_Knn_Bagging = Pipeline([('imputer' , KNNImputer()),
                                ('replacer' , KNNReplacerIQR()),
                                ('scaler' , RobustScaler()),
                                ('classifier' ,  BaggingClassifier(
                                                 base_estimator=SVC((C=10 ** logC, gamma=10 ** logGamma),
                                                 random_state = 42))
                                ])

# %%
 #Setto i parametri che dovrà usare Pipeline ad ogni iterazione
grid_Pipe_Knn_Bagging = {'imputer__n_neighbors' : [2, 5, 10,15,20] ,
                             'replacer__n_neighbors' : [2, 5, 10,15,20]
                            }

# %%
#Definisco le grid search per le pipeline
gs_Bagging_knn = model_select.GridSearchCV( Pipe_Knn_Bagging ,
                                               param_grid =  grid_Pipe_Knn_Bagging,
                                               scoring='f1_macro',
                                               cv=5,
                                               refit=True,
                                               n_jobs=-1)

# %%
# List of pipeline grids for ease of iteration.
grids = [gs_Bagging_knn]

# %%
# Dictionary of pipelines and classifier types for ease of reference.
grid_dict_pipe = {0: 'QDA-KNN-DBSCAN'}

# %%
#grids, grid_dict_pipe = get_my_pipeline()

# %%
# Fit the grid search objects and look for the best model.
print("\nMODEL OPTIMIZATIONS STARTED")
best_f1 = 0.0
best_idx = 0
best_pipe = None
for idx, pipe_gs in enumerate(grids):
    print('Currently trying model: %s' % grid_dict_pipe[idx])
    print(pipe_gs)

    # Perform grid search.
    pipe_gs.fit(train_x, train_y[target])

    # Dump detailed scores on a file.
    results_file = open(grid_dict_pipe[idx] + '_results.txt', 'w')

    # Print scores and update bests.
    print("\nGrid scores:")
    means = pipe_gs.cv_results_['mean_test_score']
    stds = pipe_gs.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds,
                                 pipe_gs.cv_results_['params']):
        print("%0.4f (+/-%0.03f) for %r" % (mean, std * 2, params))
        results_file.write("%0.4f (+/-%0.03f) for %r\n"
                           % (mean, std * 2, params))
    print("\nBest parameters:")
    print(pipe_gs.best_params_)
    print("\nBest score: %0.4f" % pipe_gs.best_score_)
    if pipe_gs.best_score_ > best_f1:
        best_f1 = pipe_gs.best_score_
        best_idx = idx
        best_pipe = pipe_gs.best_estimator_
    results_file.write("\nBest parameters:\n%r\n" % pipe_gs.best_params_)
    results_file.write("\nBest score: %0.4f\n" % pipe_gs.best_score_)

    results_file.close()
# Out:
# MODEL OPTIMIZATIONS STARTED
# Currently trying model: QDA-KNN-DBSCAN
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('imputer', KNNImputer()),
#                                        ('replacer', KNNReplacerIQR()),
#                                        ('scaler', RobustScaler()),
#                                        ('classifier',
#                                         BaggingClassifier(base_estimator=SVC(),
#                                                           random_state=42))]),
#              n_jobs=-1,
#              param_grid={'imputer__n_neighbors': [2, 5, 10, 15, 20],
#                          'replacer__n_neighbors': [2, 5, 10, 15, 20]},
#              scoring='f1_macro')
#
# Grid scores:
# 0.8088 (+/-0.016) for {'imputer__n_neighbors': 2, 'replacer__n_neighbors': 2}
# 0.8088 (+/-0.016) for {'imputer__n_neighbors': 2, 'replacer__n_neighbors': 5}
# 0.8088 (+/-0.016) for {'imputer__n_neighbors': 2, 'replacer__n_neighbors': 10}
# 0.8088 (+/-0.016) for {'imputer__n_neighbors': 2, 'replacer__n_neighbors': 15}
# 0.8088 (+/-0.016) for {'imputer__n_neighbors': 2, 'replacer__n_neighbors': 20}
# 0.8093 (+/-0.016) for {'imputer__n_neighbors': 5, 'replacer__n_neighbors': 2}
# 0.8093 (+/-0.016) for {'imputer__n_neighbors': 5, 'replacer__n_neighbors': 5}
# 0.8093 (+/-0.016) for {'imputer__n_neighbors': 5, 'replacer__n_neighbors': 10}
# 0.8093 (+/-0.016) for {'imputer__n_neighbors': 5, 'replacer__n_neighbors': 15}
# 0.8093 (+/-0.016) for {'imputer__n_neighbors': 5, 'replacer__n_neighbors': 20}
# 0.8091 (+/-0.017) for {'imputer__n_neighbors': 10, 'replacer__n_neighbors': 2}
# 0.8091 (+/-0.017) for {'imputer__n_neighbors': 10, 'replacer__n_neighbors': 5}
# 0.8091 (+/-0.017) for {'imputer__n_neighbors': 10, 'replacer__n_neighbors': 10}
# 0.8091 (+/-0.017) for {'imputer__n_neighbors': 10, 'replacer__n_neighbors': 15}
# 0.8091 (+/-0.017) for {'imputer__n_neighbors': 10, 'replacer__n_neighbors': 20}
# 0.8090 (+/-0.017) for {'imputer__n_neighbors': 15, 'replacer__n_neighbors': 2}
# 0.8090 (+/-0.017) for {'imputer__n_neighbors': 15, 'replacer__n_neighbors': 5}
# 0.8090 (+/-0.017) for {'imputer__n_neighbors': 15, 'replacer__n_neighbors': 10}
# 0.8090 (+/-0.017) for {'imputer__n_neighbors': 15, 'replacer__n_neighbors': 15}
# 0.8090 (+/-0.017) for {'imputer__n_neighbors': 15, 'replacer__n_neighbors': 20}
# 0.8088 (+/-0.018) for {'imputer__n_neighbors': 20, 'replacer__n_neighbors': 2}
# 0.8088 (+/-0.018) for {'imputer__n_neighbors': 20, 'replacer__n_neighbors': 5}
# 0.8088 (+/-0.018) for {'imputer__n_neighbors': 20, 'replacer__n_neighbors': 10}
# 0.8088 (+/-0.018) for {'imputer__n_neighbors': 20, 'replacer__n_neighbors': 15}
# 0.8088 (+/-0.018) for {'imputer__n_neighbors': 20, 'replacer__n_neighbors': 20}
#
# Best parameters:
# {'imputer__n_neighbors': 5, 'replacer__n_neighbors': 2}
#
# Best score: 0.8093
