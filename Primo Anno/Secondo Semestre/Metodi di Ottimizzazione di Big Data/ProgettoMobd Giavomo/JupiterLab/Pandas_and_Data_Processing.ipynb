# %% [markdown]
# # Introduzione a Pandas

# %%
import pandas as pd
import numpy as np

# %%
testset = pd.read_csv('training_set.csv')
testset
# Out:
#             F1        F2        F3        F4        F5        F6        F7  \
# 0    -0.555694 -0.848258  0.132180 -4.061760  1.661394  2.219988  0.360537
# 1     0.293193 -2.628978 -1.154407  0.538828 -0.169857  3.487574  0.443397
# 2    -2.078656 -0.834492  1.241461  1.010122 -1.638526  0.247378 -1.887390
# 3    -1.294256 -2.804065 -1.335397 -1.351379 -0.327137  1.199219  0.262458
# 4    -0.525611  0.024948  1.609361 -0.248425  1.533188  0.580862  0.049771
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  0.405098  0.592920  2.441859 -1.134919  2.248627  2.509097 -0.227617
# 7996 -0.404388  1.813804 -2.483380  2.093664  0.139423  2.617027  0.489677
# 7997  0.233546 -1.003142 -2.121826  1.581558  1.152723 -0.987152  0.337969
# 7998  1.120382  0.194409 -0.672968  0.005154  2.290353  4.112554  0.720367
# 7999  0.994641 -1.185386 -3.610239  0.185566 -1.534623  3.021333 -0.721372
#
# ...

# %%
# Estraggo parti di tabella partendo dall'alto, possiamo anche specificare quante
testset.head()
# Out:
#          F1        F2        F3        F4        F5        F6        F7  \
# 0 -0.555694 -0.848258  0.132180 -4.061760  1.661394  2.219988  0.360537
# 1  0.293193 -2.628978 -1.154407  0.538828 -0.169857  3.487574  0.443397
# 2 -2.078656 -0.834492  1.241461  1.010122 -1.638526  0.247378 -1.887390
# 3 -1.294256 -2.804065 -1.335397 -1.351379 -0.327137  1.199219  0.262458
# 4 -0.525611  0.024948  1.609361 -0.248425  1.533188  0.580862  0.049771
#
#          F8        F9       F10  ...       F12       F13       F14       F15  \
# 0  2.537116 -0.613588  2.078144  ... -2.492234  0.808907 -1.078887  3.438161
# 1 -0.006410 -0.125778  1.223669  ... -1.723842  1.772836  0.467387 -1.501851
# 2 -1.331368 -2.159086  0.002788  ... -1.686278 -1.047410 -1.133299 -1.953928
# 3  0.825120 -0.638883  1.660732  ...  4.437570 -0.093413  2.637345 -2.415704
# 4 -0.430270 -0.714264 -0.186867  ...  0.404803 -0.733368  1.288384 -1.646543
#
#         F16       F17       F18       F19       F20  CLASS
# ...

# %%
# Estraggo parti di tabella partendo dal basso, possiamo anche specificare quante
testset.tail()
# Out:
#             F1        F2        F3        F4        F5        F6        F7  \
# 7995  0.405098  0.592920  2.441859 -1.134919  2.248627  2.509097 -0.227617
# 7996 -0.404388  1.813804 -2.483380  2.093664  0.139423  2.617027  0.489677
# 7997  0.233546 -1.003142 -2.121826  1.581558  1.152723 -0.987152  0.337969
# 7998  1.120382  0.194409 -0.672968  0.005154  2.290353  4.112554  0.720367
# 7999  0.994641 -1.185386 -3.610239  0.185566 -1.534623  3.021333 -0.721372
#
#             F8        F9       F10  ...       F12       F13       F14  \
# 7995  0.275321 -0.274926 -0.595862  ... -0.169544 -0.255823  2.695956
# 7996  1.387914 -0.363073  0.030530  ...  0.124103  0.056482 -0.333988
# 7997 -4.654229 -0.417682 -1.260857  ...  2.469214  2.782867  0.888288
# 7998  0.563533 -1.009534 -1.551473  ...  0.607569  3.102179  4.237942
# 7999 -3.250708 -0.034000 -0.102102  ... -3.273256  3.908861  0.809098
#
#            F15       F16       F17       F18       F19       F20  CLASS
# ...

# %%
# Seleziona la riga
testset.iloc[10]
# Out:
# F1      -1.211321
# F2      -0.325700
# F3       1.345666
# F4      -2.203631
# F5       0.091878
# F6      -4.162786
# F7       0.822559
# F8      -0.817427
# F9      -0.499763
# F10      1.740538
# F11      0.247072
# F12      3.408854
# F13     -1.692536
# F14      2.577782
# F15      1.205809
# F16      0.052272
# F17      3.132447
# F18      0.052272
# F19     -1.585862
# F20      1.345666
# CLASS    3.000000
# Name: 10, dtype: float64

# %%
# Seleziona l'indice
testset.loc[10]
# Out:
# F1      -1.211321
# F2      -0.325700
# F3       1.345666
# F4      -2.203631
# F5       0.091878
# F6      -4.162786
# F7       0.822559
# F8      -0.817427
# F9      -0.499763
# F10      1.740538
# F11      0.247072
# F12      3.408854
# F13     -1.692536
# F14      2.577782
# F15      1.205809
# F16      0.052272
# F17      3.132447
# F18      0.052272
# F19     -1.585862
# F20      1.345666
# CLASS    3.000000
# Name: 10, dtype: float64

# %%
testset.iloc[0,1]
# Out:
# -0.8482578577147615

# %%
print(f'Numero di elementi del testset = {len(testset)}')
# Out:
# Numero di elementi del testset = 8000

# %%
testset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   F1      7994 non-null   float64
#  1   F2      7994 non-null   float64
#  2   F3      7999 non-null   float64
#  3   F4      7999 non-null   float64
#  4   F5      7996 non-null   float64
#  5   F6      7994 non-null   float64
#  6   F7      7996 non-null   float64
#  7   F8      7991 non-null   float64
#  8   F9      7994 non-null   float64
#  9   F10     7994 non-null   float64
#  10  F11     7995 non-null   float64
#  11  F12     7994 non-null   float64
#  12  F13     7997 non-null   float64
#  13  F14     7990 non-null   float64
#  14  F15     7998 non-null   float64
#  15  F16     7994 non-null   float64
#  16  F17     7996 non-null   float64
#  17  F18     7993 non-null   float64
#  18  F19     7995 non-null   float64
#  19  F20     7997 non-null   float64
# ...

# %%
# Scelgo la colonna che voglio
testset['CLASS']
# Out:
# 0       2
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7995    1
# 7996    2
# 7997    0
# 7998    1
# 7999    3
# Name: CLASS, Length: 8000, dtype: int64

# %%
# Scelgo colonna che voglio
testset.CLASS
# Out:
# 0       2
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7995    1
# 7996    2
# 7997    0
# 7998    1
# 7999    3
# Name: CLASS, Length: 8000, dtype: int64

# %%
testset.columns
# Out:
# Index(['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11',
#        'F12', 'F13', 'F14', 'F15', 'F16', 'F17', 'F18', 'F19', 'F20', 'CLASS'],
#       dtype='object')

# %%
for idx, col in enumerate(testset.columns):
    print(idx ,' ', col)
# Out:
# 0   F1
# 1   F2
# 2   F3
# 3   F4
# 4   F5
# 5   F6
# 6   F7
# 7   F8
# 8   F9
# 9   F10
# 10   F11
# 11   F12
# 12   F13
# 13   F14
# 14   F15
# 15   F16
# 16   F17
# 17   F18
# 18   F19
# 19   F20
# 20   CLASS

# %%
# isna = is not aviable
testset.isna()
# Out:
#          F1     F2     F3     F4     F5     F6     F7     F8     F9    F10  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7995  False  False  False  False  False  False  False  False  False  False
# 7996  False  False  False  False  False  False  False  False  False  False
# 7997  False  False  False  False  False  False  False  False  False  False
# 7998  False  False  False  False  False  False  False  False  False  False
# 7999  False  False  False  False  False  False  False  False  False  False
#
# ...
